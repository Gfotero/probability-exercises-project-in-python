# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
import numpy as np
import random
contador=0
for i in range(1000):
    Lanzar_A=random.randint(1,6)
    Lanzar_B=random.randint(1,6)
    suma=Lanzar_A+Lanzar_B
    if suma>7 or suma%2==0:
        contador+=1
prob= (contador/1000)*100       
print('La probabilidad de obtener al lanzar dos dados un suma mayor a 7 o un numero par, es igual a:', round(prob,2),'%')
# Out:
# La probabilidad de obtener al lanzar dos dados un suma mayor a 7 o un numero par, es igual a: 64.5 %

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "Blanca"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Roja"
    else:
        ball_box[i] = "Verde"

#print(ball_box)

# TODO

Cont_RyB=0
Cont_iguales=0
for j in range(1000):
    BB=0
    BR=0
    BV=0
    for k in range(5):
        calidad=0
        Tomar_Bola=random.randint(0,59)
        #print(Tomar_Bola)
        if Tomar_Bola<10:
            BB+=1
            #print('bola blanca',Tomar_Bola)
        elif (Tomar_Bola>9) and (Tomar_Bola<30):
            BR+=1
            #print('bola roja',Tomar_Bola)
        else:
            BV+=1
            #print('bola verde',Tomar_Bola)
        calidad=1
    if BB==3 and BR==2:
        Cont_RyB+=1
        #print('3 blancas y 2 rojas ',Cont_RyB)
        #print(j,calidad)
    elif BB==5 or BR==5 or BV==5:
        Cont_iguales+=1
        #print('todas iguales ',Cont_iguales)

probByR=(Cont_RyB/1000)*100
probIguales=(Cont_iguales/1000)*100

print('La probabilidad de sacar 3 bolas blancas y 2 rojas en una muestra con reemplazo es igual a:',round(probByR,2),'%')
print('La probabilidad de sacar las 5 bolas de un mismo color en una muestra con reemplazo es igual a:',round(probIguales,2),'%')
# Out:
# La probabilidad de sacar 3 bolas blancas y 2 rojas en una muestra con reemplazo es igual a: 0.5 %
# La probabilidad de sacar las 5 bolas de un mismo color en una muestra con reemplazo es igual a: 3.1 %
